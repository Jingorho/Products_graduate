# %%
###############################
# ライブラリの読み込みとJupyter Notebookの設定
###############################
import pandas as pd # csvファイルとかを扱うためのライブラリ
import numpy as np # 数値計算を扱うためのライブラリ
import matplotlib.pyplot as plt # グラフ表示するためのライブラリ
import os # ファイルとディレクトリ処理のためのライブラリ
import glob # ファイル検索のライブラリ
# %matplotlib inline 
# Jupyter Notebook上にグラフを表示させるコマンド



###############################
# メイン関数 JupyterNotebookを実行するとこの関数が実行される
###############################
def main():
    
    # 平滑化処理をするときの移動平均の幅. 
    # ここの値を変えると平均をとる幅が変わる
    windowWidth = 50
    
    # [A] (デバッグ用) 特定のcsvファイル一つだけを実行する場合はこちら
#     SpecificCsvFile = "視線データ/1211_1_1/bd/bd5.csv"
#     MakeInterpolatedCsv(SpecificCsvFile, windowWidth)
    
    # [B] このスクリプトが置かれた場所からファイルを探索して信号処理を行う
    LoopProcessDir(windowWidth)
    
    
###############################
# 
###############################
def interpCsv(fi, _windowWidth):
    
    print("\n  - - - Start interpCsv() - - -")
    
    ###############################
    # データ読み込みと前処理
    ###############################
    colnames = ["left", "right", "leftValid", "rightValid"] # 列名を作成
    df = pd.read_csv(fi, header = None, names = colnames) # 作成した列名でcsv読み込み
    print(df.head()) # 最初の5行表示してデータの様子をチラ見
    print("NAの行数:\n" + str(len(df) - df.count())) # データの様子をチラ見

    # もともとNaNだろうが値あろうが、validationに基づいて無効データをNaNで上書き
    # (値があってもvalidationが4の場合もあるかも?のため)
    df.left[df.leftValid == 4] = pd.np.nan
    df.right[df.rightValid == 4] = pd.np.nan
    
#     # 数値データでないノイズとかがまざってるときあるのでNaNで置き換え
#     # 左
#     left_isStr = [isinstance(df.left[i], str) for i in range(0, len(df.left), 1)]
#     df.left = np.where(left_isStr, np.nan, df.left)
#     print(str(sum(left_isStr)) + " string values are converted to NaN")
#     # 右
#     right_isStr = [isinstance(df.right[i], str) for i in range(0, len(df.right), 1)]
#     df.right = np.where(right_isStr, np.nan, df.right)
#     print(str(sum(right_isStr)) + " string values are converted to NaN")
#     print(df.head())
    
    
    ###############################
    # 線形補間処理
    ###############################
    # 左
    y_left = df.left.interpolate() # 線形補間したyの値
#     plt.plot(x, y_left) # 線形補間 後のグラフ
#     plt.plot(x, df.left) # 線形補間 前のグラフ
#     plt.show() # グラフ表示
    # 右
    y_right = df.right.interpolate() # 線形補間したyの値
#     plt.plot(x, y_right) # 線形補間 後のグラフ
#     plt.plot(x, df.right) # 線形補間 前のグラフ
#     plt.show() # グラフ表示
    
    # (デバッグ用) 欠損値あった部分だけ拡大してグラフ表示
    # NaNId = np.where(df["leftValid"] == 4)[0] # タプルの0要素目(0列目)
    # NaNRanges = pd.Series(range(NaNId[0] - 100, NaNId[0] + 100, 1)) # NaN周辺
    # y_NaNRanges = pd.Series(df.left.interpolate().iloc[NaNRanges])
    # plt.plot(NaNRanges, y_NaNRanges)
    # plt.show()


    ###############################
    # 平滑化処理 - とりあえず移動平均
    ###############################
    # 左
    y_left_rol = y_left.rolling(window = _windowWidth, min_periods=1).mean() # 移動平均計算. 簡単すぎて笑うわ
    # 右
    y_right_rol = y_right.rolling(window = _windowWidth, min_periods=1).mean() # 移動平均計算. 簡単すぎて笑うわ
    
    
    # 移動平均で窓関数をあててNaNになった最初の方の行や、
    # 元からのNaNをデータ列の平均値で埋める
    print(str(y_left_rol.isnull().sum()) + " NaN values <- mean " + str(np.nanmean(y_left_rol)))
    print(str(y_right_rol.isnull().sum()) + " NaN values <- mean " + str(np.nanmean(y_right_rol)))
    y_left_rol = y_left_rol.fillna(np.nanmean(y_left_rol))
    y_right_rol = y_right_rol.fillna(np.nanmean(y_right_rol))
    
    
    ###############################
    # グラフ表示
    ###############################
    x = pd.Series(range(0, len(df.left), 1)) # グラフ表示用のx軸の値

    plt.plot(x, y_left) # 線形補間 後のグラフ
    plt.plot(x, df.left) # 線形補間 前のグラフ
#     plt.plot(x, y_left_rol) # 移動平均後のグラフ
    plt.show() # グラフ表示
#     plt.plot(x, y_right) # 線形補間 後のグラフ
#     plt.plot(x, df.right) # 線形補間 前のグラフ
#     plt.plot(x, y_right_rol) # 移動平均後のグラフ
#     plt.show() # グラフ表示
    

    ###############################
    # 処理後の出力用データフレーム作成
    ###############################
    outputDataFrame = pd.concat([y_left_rol, y_right_rol], axis = 1)
    print("Output : \n")
    print(outputDataFrame.head())
    
    print("\n  - - - End interpCsv() - - -")
    
    
    return outputDataFrame
    
    




###############################
# ディレクトリで処理を回す関数
###############################
def LoopProcessDir(_windowWidth):
    dataRootPath = "視線データ/"
    dirList = os.listdir(dataRootPath) # dataRootPath内に存在するディレクトリ一覧取得
    edMatTypes = ["bd", "nw"]
    print( "Length of Directries : " + str(len(dirList)) )
    
    # 取得したディレクトリ一覧の数分だけループを回す
    for fileNum in range(1, len(dirList), 1):
        # "bd"か"nw"かでループを回す
        for edMatType in edMatTypes:
            # 取得したディレクトリの中に存在してるcsvファイルの数分だけパスを取得
            path = str(dataRootPath + dirList[fileNum]) + "/" + edMatType + "/"
            fileList = glob.glob(path + edMatType + '[0-9].csv') # 数値部分は正規表現
            
            # 取得したディレクトリ内に"bd1.csv"とかいう名前のファイルが一つでもあれば
            if(fileList is not None):
                # "bd1.csv", "bd2.csv", ...とファイルの数分だけループを回す
                for file in fileList:
                    # 線形補間の処理へ
                    MakeInterpolatedCsv(file, _windowWidth)
                    
    

###############################
# 指定したファイルで線形補間と平滑化処理
###############################
def MakeInterpolatedCsv(_file, _windowWidth):
    
    print("------------------------------------------")
    print("\n\n> Reading " + _file + " ...")
    
    # 線形補間の処理
    outputDf = interpCsv(_file, _windowWidth)
    
    fileId = _file.strip(".csv")[-1] # 番号("bd1.csv"のうち"1")だけ取り出し
    fileEdMatType = _file.strip(fileId + ".csv")[-2:] # "bd1.csv"のうち"bd"
    filePath = _file.strip(fileEdMatType + fileId + ".csv") # パスのうち"bd/bd1.csv"を除いたパス
    
    # "補間済"というディレクトリがなければ作るし、あれば何もしない
    if not os.path.isdir(filePath + '補間済'):
        os.mkdir(filePath + '補間済') # ディレクトリ作る
        print(" >> Made : " + filePath + '補間済')
    else:
        print(" >> Already Exist : " + filePath + "補間済")
    
    # 出力用のパス作成
    outputCsvPath = filePath + '補間済/' + fileEdMatType + fileId + '_pd.csv'
    # csv出力
    outputDf.to_csv(outputCsvPath, index = None)

    print("> Writing " + outputCsvPath + " ... \n\n")
    
    
    
    
###############################
# main関数を実行する処理
###############################
if __name__ == '__main__':
  main()
# Out:
# Length of Directries : 21
# ------------------------------------------
#
#
# > Reading 視線データ/1212_2_1/bd/bd1.csv ...
#
#   - - - Start interpCsv() - - -
#    left  right  leftValid  rightValid
# 0  3.77   3.76          0           0
# 1  3.76   3.76          0           0
# 2  3.77   3.76          0           0
# 3  3.76   3.77          0           0
# 4  3.77   3.77          0           0
# NAの行数:
# left          392
# right         473
# leftValid       0
# rightValid      0
# dtype: int64
# /Users/yukako/.pyenv/versions/anaconda3-5.1.0/lib/python3.6/site-packages/ipykernel_launcher.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/yukako/.pyenv/versions/anaconda3-5.1.0/lib/python3.6/site-packages/ipykernel_launcher.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 0 NaN values <- mean 3.296266825963336
# 0 NaN values <- mean 3.2459844249854126
# Output :
#
#        left   right
# 0  3.770000  3.7600
# 1  3.765000  3.7600
# 2  3.766667  3.7600
# 3  3.765000  3.7625
# 4  3.766000  3.7640
#
#   - - - End interpCsv() - - -
#  >> Already Exist : 視線データ/1212_2_1/bd/補間済
# > Writing 視線データ/1212_2_1/bd/補間済/bd1_pd.csv ...
#
#
# ------------------------------------------
#
#
# > Reading 視線データ/1212_2_1/bd/bd2.csv ...
#
#   - - - Start interpCsv() - - -
#    left  right  leftValid  rightValid
# 0  2.80    NaN          0           4
# 1  2.99    NaN          0           4
# 2  2.61   2.60          0           0
# 3  3.03    NaN          0           4
# 4   NaN   2.28          4           0
# NAの行数:
# left          1075
# right          822
# leftValid        0
# rightValid       0
# dtype: int64
# 0 NaN values <- mean 3.330612901630887
# 2 NaN values <- mean 3.2854769992433166
# Output :
#
#        left     right
# 0  2.800000  3.285477
# 1  2.895000  3.285477
# 2  2.800000  2.600000
# 3  2.857500  2.520000
# 4  2.892078  2.440000
#
#   - - - End interpCsv() - - -
#  >> Already Exist : 視線データ/1212_2_1/bd/補間済
# > Writing 視線データ/1212_2_1/bd/補間済/bd2_pd.csv ...
#
#
# ------------------------------------------
#
#
# > Reading 視線データ/1212_2_1/bd/bd3.csv ...
#
#   - - - Start interpCsv() - - -
#    left  right  leftValid  rightValid
# 0  3.10   2.95          0           0
# 1  3.09   2.94          0           0
# 2  3.08   2.93          0           0
# 3  3.06   2.92          0           0
# 4  3.06   2.90          0           0
# NAの行数:
# left          447
# right         406
# leftValid       0
# rightValid      0
# dtype: int64
# 0 NaN values <- mean 3.5585941745148038
# 0 NaN values <- mean 3.500859780221293
# Output :
#
#      left  right
# 0  3.1000  2.950
# 1  3.0950  2.945
# 2  3.0900  2.940
# 3  3.0825  2.935
# 4  3.0780  2.928
#
#   - - - End interpCsv() - - -
#  >> Already Exist : 視線データ/1212_2_1/bd/補間済
# > Writing 視線データ/1212_2_1/bd/補間済/bd3_pd.csv ...
#
#
# ------------------------------------------
#
#
# > Reading 視線データ/1212_2_1/bd/bd6.csv ...
#
#   - - - Start interpCsv() - - -
#    left  right  leftValid  rightValid
# 0  4.01   3.93          0           0
# 1  4.01   3.94          0           0
# 2  4.02   3.94          0           0
# 3  4.02   3.94          0           0
# 4  4.02   3.94          0           0
# NAの行数:
# left          776
# right         374
# leftValid       0
# rightValid      0
# dtype: int64
# 0 NaN values <- mean 3.521280408373319
# 0 NaN values <- mean 3.512579595624407
# Output :
#
#        left     right
# 0  4.010000  3.930000
# 1  4.010000  3.935000
# 2  4.013333  3.936667
# 3  4.015000  3.937500
# 4  4.016000  3.938000
#
#   - - - End interpCsv() - - -
#  >> Already Exist : 視線データ/1212_2_1/bd/補間済
# > Writing 視線データ/1212_2_1/bd/補間済/bd6_pd.csv ...
#
#
# ------------------------------------------
#
#
# > Reading 視線データ/1212_2_1/bd/bd4.csv ...
#
#   - - - Start interpCsv() - - -
#    left  right  leftValid  rightValid
# 0   NaN    NaN          4           4
# 1   NaN    NaN          4           4
# 2  3.78   3.61          0           0
# 3  3.76   3.59          0           0
# 4  3.74   3.56          0           0
# NAの行数:
# left          630
# right         527
# leftValid       0
# rightValid      0
# dtype: int64
# 2 NaN values <- mean 3.626424047849913
# 2 NaN values <- mean 3.595589302414014
# Output :
#
#        left     right
# 0  3.626424  3.595589
# 1  3.626424  3.595589
# 2  3.780000  3.610000
# 3  3.770000  3.600000
# 4  3.760000  3.586667
#
#   - - - End interpCsv() - - -
#  >> Already Exist : 視線データ/1212_2_1/bd/補間済
# > Writing 視線データ/1212_2_1/bd/補間済/bd4_pd.csv ...
#
#
# ------------------------------------------
#
#
# > Reading 視線データ/1212_2_1/bd/bd5.csv ...
#
#   - - - Start interpCsv() - - -
#    left  right  leftValid  rightValid
# 0  3.87   3.98          0           0
# 1  3.89   3.98          0           0
# 2  3.90   3.99          0           0
# 3  3.91   3.99          0           0
# 4  3.92   4.01          0           0
# NAの行数:
# left          1458
# right          764
# leftValid        0
# rightValid       0
# dtype: int64
# 0 NaN values <- mean 3.6243724260946557
# 0 NaN values <- mean 3.6254435166801424
# Output :
#
#        left     right
# 0  3.870000  3.980000
# 1  3.880000  3.980000
# 2  3.886667  3.983333
# 3  3.892500  3.985000
# 4  3.898000  3.990000
#
#   - - - End interpCsv() - - -
#  >> Already Exist : 視線データ/1212_2_1/bd/補間済
# > Writing 視線データ/1212_2_1/bd/補間済/bd5_pd.csv ...
#
#
# ------------------------------------------
#
#
# > Reading 視線データ/1221_1_2/nw/nw6.csv ...
#
#   - - - Start interpCsv() - - -
#    left  right  leftValid  rightValid
# 0   NaN    NaN          4           4
# 1   NaN    NaN          4           4
# 2   NaN    NaN          4           4
# 3   NaN    NaN          4           4
# 4   NaN    NaN          4           4
# NAの行数:
# left          386
# right         385
# leftValid       0
# rightValid      0
# dtype: int64
# 19 NaN values <- mean 2.8833413580523555
# 19 NaN values <- mean 2.8888048279395413
# Output :
#
#        left     right
# 0  2.883341  2.888805
# 1  2.883341  2.888805
# 2  2.883341  2.888805
# 3  2.883341  2.888805
# 4  2.883341  2.888805
#
#   - - - End interpCsv() - - -
#  >> Already Exist : 視線データ/1221_1_2/nw/補間済
# > Writing 視線データ/1221_1_2/nw/補間済/nw6_pd.csv ...
#
#
# ------------------------------------------
#
#
# > Reading 視線データ/1221_1_2/nw/nw4.csv ...
#
#   - - - Start interpCsv() - - -
#    left  right  leftValid  rightValid
# 0  3.00   2.93          0           0
# 1  2.99   2.93          0           0
# 2  3.00   2.94          0           0
# 3  2.99   2.93          0           0
# 4  3.00   2.94          0           0
# NAの行数:
# left          719
# right         758
# leftValid       0
# rightValid      0
# dtype: int64
# 0 NaN values <- mean 2.7864570064097225
# 0 NaN values <- mean 2.7622687778244366
# Output :
#
#        left     right
# 0  3.000000  2.930000
# 1  2.995000  2.930000
# 2  2.996667  2.933333
# 3  2.995000  2.932500
# 4  2.996000  2.934000
#
#   - - - End interpCsv() - - -
#  >> Already Exist : 視線データ/1221_1_2/nw/補間済
# > Writing 視線データ/1221_1_2/nw/補間済/nw4_pd.csv ...
#
#
# ------------------------------------------
#
#
# > Reading 視線データ/1221_1_2/nw/nw5.csv ...
#
#   - - - Start interpCsv() - - -
#    left  right  leftValid  rightValid
# 0  2.99   3.05          0           0
# 1  2.99   3.05          0           0
# 2  2.98   3.04          0           0
# 3  2.97   3.03          0           0
# 4  2.96   3.02          0           0
# NAの行数:
# left          545
# right         524
# leftValid       0
# rightValid      0
# dtype: int64
# 0 NaN values <- mean 2.9600963970546155
# 0 NaN values <- mean 2.9100247009254154
# Output :
#
#        left     right
# 0  2.990000  3.050000
# 1  2.990000  3.050000
# 2  2.986667  3.046667
# 3  2.982500  3.042500
# 4  2.978000  3.038000
#
#   - - - End interpCsv() - - -
#  >> Already Exist : 視線データ/1221_1_2/nw/補間済
# > Writing 視線データ/1221_1_2/nw/補間済/nw5_pd.csv ...
#
#
# ------------------------------------------
#
#
# > Reading 視線データ/1221_1_2/nw/nw1.csv ...
#
#   - - - Start interpCsv() - - -
#    left  right  leftValid  rightValid
# 0  2.88   2.91          0           0
# 1  2.88   2.91          0           0
# 2  2.87   2.90          0           0
# 3  2.87   2.91          0           0
# 4  2.86   2.90          0           0
# NAの行数:
# left          564
# right         544
# leftValid       0
# rightValid      0
# dtype: int64
# 0 NaN values <- mean 2.848645972380963
# 0 NaN values <- mean 2.823605920474052
# Output :
#
#        left     right
# 0  2.880000  2.910000
# 1  2.880000  2.910000
# 2  2.876667  2.906667
# 3  2.875000  2.907500
# 4  2.872000  2.906000
#
#   - - - End interpCsv() - - -
#  >> Already Exist : 視線データ/1221_1_2/nw/補間済
# > Writing 視線データ/1221_1_2/nw/補間済/nw1_pd.csv ...
#
#
# ------------------------------------------
#
#
# > Reading 視線データ/1221_1_2/nw/nw2.csv ...
#
#   - - - Start interpCsv() - - -
#    left  right  leftValid  rightValid
# 0  2.76   2.73          0           0
# 1  2.76   2.73          0           0
# 2  2.77   2.74          0           0
# 3  2.78   2.74          0           0
# 4  2.78   2.74          0           0
# NAの行数:
# left          116
# right          99
# leftValid       0
# rightValid      0
# dtype: int64
# 0 NaN values <- mean 3.0281517148052046
# 0 NaN values <- mean 3.063459592471219
# Output :
#
#        left     right
# 0  2.760000  2.730000
# 1  2.760000  2.730000
# 2  2.763333  2.733333
# 3  2.767500  2.735000
# 4  2.770000  2.736000
#
#   - - - End interpCsv() - - -
#  >> Already Exist : 視線データ/1221_1_2/nw/補間済
# > Writing 視線データ/1221_1_2/nw/補間済/nw2_pd.csv ...
#
#
# ------------------------------------------
#
#
# > Reading 視線データ/1221_1_2/nw/nw3.csv ...
#
#   - - - Start interpCsv() - - -
#    left  right  leftValid  rightValid
# 0  2.74   2.83          0           0
# 1  2.76   2.83          0           0
# 2  2.77   2.83          0           0
# 3  2.77   2.84          0           0
# 4  2.79   2.86          0           0
# NAの行数:
# left          1128
# right         1150
# leftValid        0
# rightValid       0
# dtype: int64
# 0 NaN values <- mean 2.891889182793455
# 0 NaN values <- mean 2.8450998205193296
# Output :
#
#        left   right
# 0  2.740000  2.8300
# 1  2.750000  2.8300
# 2  2.756667  2.8300
# 3  2.760000  2.8325
# 4  2.766000  2.8380
#
#   - - - End interpCsv() - - -
#  >> Already Exist : 視線データ/1221_1_2/nw/補間済
# > Writing 視線データ/1221_1_2/nw/補間済/nw3_pd.csv ...
#
#
# ------------------------------------------
#
#
# > Reading 視線データ/1214_2_1/bd/bd1.csv ...
#
#   - - - Start interpCsv() - - -
#    left  right  leftValid  rightValid
# 0  4.90   4.68          0           0
# 1  4.90   4.68          0           0
# 2  4.93   4.68          0           0
# 3  4.96   4.71          0           0
# 4  4.96   4.71          0           0
# NAの行数:
# left          416
# right         382
# leftValid       0
# rightValid      0
# dtype: int64
# 0 NaN values <- mean 4.77517391163725
# 0 NaN values <- mean 4.513103628707534
# Output :
#
#      left   right
# 0  4.9000  4.6800
# 1  4.9000  4.6800
# 2  4.9100  4.6800
# 3  4.9225  4.6875
# 4  4.9300  4.6920
#
#   - - - End interpCsv() - - -
#  >> Already Exist : 視線データ/1214_2_1/bd/補間済
# > Writing 視線データ/1214_2_1/bd/補間済/bd1_pd.csv ...
#
#
# ------------------------------------------
#
#
# > Reading 視線データ/1214_2_1/bd/bd2.csv ...
#
#   - - - Start interpCsv() - - -
#    left  right  leftValid  rightValid
# 0  4.67   4.47          0           0
# 1  4.66   4.47          0           0
# 2  4.66   4.47          0           0
# 3  4.66   4.47          0           0
# 4  4.65   4.47          0           0
# NAの行数:
# left          972
# right         898
# leftValid       0
# rightValid      0
# dtype: int64
# 0 NaN values <- mean 4.625230901995727
# 0 NaN values <- mean 4.392454541269569
# Output :
#
#        left  right
# 0  4.670000   4.47
# 1  4.665000   4.47
# 2  4.663333   4.47
# 3  4.662500   4.47
# 4  4.660000   4.47
#
#   - - - End interpCsv() - - -
#  >> Already Exist : 視線データ/1214_2_1/bd/補間済
# > Writing 視線データ/1214_2_1/bd/補間済/bd2_pd.csv ...
#
#
# ------------------------------------------
#
#
# > Reading 視線データ/1214_2_1/bd/bd3.csv ...
#
#   - - - Start interpCsv() - - -
#    left  right  leftValid  rightValid
# 0  4.36   4.27          0           0
# 1  4.36   4.28          0           0
# 2  4.37   4.28          0           0
# 3  4.37   4.29          0           0
# 4  4.38   4.31          0           0
# NAの行数:
# left          360
# right         344
# leftValid       0
# rightValid      0
# dtype: int64
# 0 NaN values <- mean 4.96543152300197
# 0 NaN values <- mean 4.65903455467582
# Output :
#
#        left     right
# 0  4.360000  4.270000
# 1  4.360000  4.275000
# 2  4.363333  4.276667
# 3  4.365000  4.280000
# 4  4.368000  4.286000
#
#   - - - End interpCsv() - - -
#  >> Already Exist : 視線データ/1214_2_1/bd/補間済
# > Writing 視線データ/1214_2_1/bd/補間済/bd3_pd.csv ...
#
#
# ------------------------------------------
#
#
# > Reading 視線データ/1214_2_1/bd/bd6.csv ...
#
#   - - - Start interpCsv() - - -
#    left  right  leftValid  rightValid
# 0  4.84   4.51          0           0
# 1  4.82   4.49          0           0
# 2  4.79   4.46          0           0
# 3  4.77   4.43          0           0
# 4  4.74   4.41          0           0
# NAの行数:
# left          616
# right         631
# leftValid       0
# rightValid      0
# dtype: int64
# 0 NaN values <- mean 4.6993495439536614
# 0 NaN values <- mean 4.428327027256467
# Output :
#
#        left     right
# 0  4.840000  4.510000
# 1  4.830000  4.500000
# 2  4.816667  4.486667
# 3  4.805000  4.472500
# 4  4.792000  4.460000
#
#   - - - End interpCsv() - - -
#  >> Already Exist : 視線データ/1214_2_1/bd/補間済
# > Writing 視線データ/1214_2_1/bd/補間済/bd6_pd.csv ...
#
#
# ------------------------------------------
#
#
# > Reading 視線データ/1214_2_1/bd/bd4.csv ...
#
#   - - - Start interpCsv() - - -
#    left  right  leftValid  rightValid
# 0  4.82   4.53          0           0
# 1  4.83   4.53          0           0
# 2  4.84   4.54          0           0
# 3  4.85   4.54          0           0
# 4  4.86   4.55          0           0
# NAの行数:
# left          719
# right         738
# leftValid       0
# rightValid      0
# dtype: int64
# 0 NaN values <- mean 4.75413932047156
# 0 NaN values <- mean 4.491089428090156
# Output :
#
#     left     right
# 0  4.820  4.530000
# 1  4.825  4.530000
# 2  4.830  4.533333
# 3  4.835  4.535000
# 4  4.840  4.538000
#
#   - - - End interpCsv() - - -
#  >> Already Exist : 視線データ/1214_2_1/bd/補間済
# > Writing 視線データ/1214_2_1/bd/補間済/bd4_pd.csv ...
#
#
# ------------------------------------------
#
#
# > Reading 視線データ/1214_2_1/bd/bd5.csv ...
#
#   - - - Start interpCsv() - - -
#    left  right  leftValid  rightValid
# 0  5.13   4.89          0           0
# 1  5.12   4.89          0           0
# 2  5.11   4.88          0           0
# 3  5.09   4.88          0           0
# 4  5.08   4.87          0           0
# NAの行数:
# left          359
# right         289
# leftValid       0
# rightValid      0
# dtype: int64
# 0 NaN values <- mean 4.686957085882581
# 0 NaN values <- mean 4.440808955731136
# Output :
#
#      left     right
# 0  5.1300  4.890000
# 1  5.1250  4.890000
# 2  5.1200  4.886667
# 3  5.1125  4.885000
# 4  5.1060  4.882000
#
#   - - - End interpCsv() - - -
#  >> Already Exist : 視線データ/1214_2_1/bd/補間済
# > Writing 視線データ/1214_2_1/bd/補間済/bd5_pd.csv ...
#
#
# ------------------------------------------
#
#
# > Reading 視線データ/1214_2_1/nw/nw6.csv ...
#
#   - - - Start interpCsv() - - -
#    left  right  leftValid  rightValid
# 0  5.02   4.73          0           0
# 1  5.03   4.74          0           0
# 2  5.04   4.75          0           0
# 3  5.04   4.75          0           0
# 4  5.05   4.75          0           0
# NAの行数:
# left          397
# right         397
# leftValid       0
# rightValid      0
# dtype: int64
# 0 NaN values <- mean 4.6744167269858234
# 0 NaN values <- mean 4.416536526935564
# Output :
#
#      left   right
# 0  5.0200  4.7300
# 1  5.0250  4.7350
# 2  5.0300  4.7400
# 3  5.0325  4.7425
# 4  5.0360  4.7440
#
#   - - - End interpCsv() - - -
#  >> Already Exist : 視線データ/1214_2_1/nw/補間済
# > Writing 視線データ/1214_2_1/nw/補間済/nw6_pd.csv ...
#
#
# ------------------------------------------
#
#
# > Reading 視線データ/1214_2_1/nw/nw4.csv ...
#
#   - - - Start interpCsv() - - -
#    left  right  leftValid  rightValid
# 0  4.60   4.47          0           0
# 1  4.59   4.47          0           0
# 2  4.59   4.47          0           0
# 3  4.59   4.48          0           0
# 4  4.59   4.47          0           0
# NAの行数:
# left          535
# right         485
# leftValid       0
# rightValid      0
# dtype: int64
# 0 NaN values <- mean 4.716918618275826
# 0 NaN values <- mean 4.4559367040183115
# Output :
#
#        left   right
# 0  4.600000  4.4700
# 1  4.595000  4.4700
# 2  4.593333  4.4700
# 3  4.592500  4.4725
# 4  4.592000  4.4720
#
#   - - - End interpCsv() - - -
#  >> Already Exist : 視線データ/1214_2_1/nw/補間済
# > Writing 視線データ/1214_2_1/nw/補間済/nw4_pd.csv ...
#
#
# ------------------------------------------
#
#
# > Reading 視線データ/1214_2_1/nw/nw5.csv ...
#
#   - - - Start interpCsv() - - -
#    left  right  leftValid  rightValid
# 0   NaN    NaN          4           4
# 1   NaN    NaN          4           4
# 2   NaN    NaN          4           4
# 3  3.35    NaN          0           4
# 4  3.57   3.59          0           0
# NAの行数:
# left          154
# right         128
# leftValid       0
# rightValid      0
# dtype: int64
# 3 NaN values <- mean 4.830146043539469
# 4 NaN values <- mean 4.5375431446711
# Output :
#
#        left     right
# 0  4.830146  4.537543
# 1  4.830146  4.537543
# 2  4.830146  4.537543
# 3  3.350000  4.537543
# 4  3.460000  3.590000
#
#   - - - End interpCsv() - - -
#  >> Already Exist : 視線データ/1214_2_1/nw/補間済
# > Writing 視線データ/1214_2_1/nw/補間済/nw5_pd.csv ...
#
#
# ------------------------------------------
#
#
# > Reading 視線データ/1214_2_1/nw/nw1.csv ...
#
#   - - - Start interpCsv() - - -
#    left  right  leftValid  rightValid
# 0  5.03   4.69          0           0
# 1  5.02   4.69          0           0
# 2  5.02   4.69          0           0
# 3  5.02   4.69          0           0
# 4  5.01   4.68          0           0
# NAの行数:
# left          201
# right         162
# leftValid       0
# rightValid      0
# dtype: int64
# 0 NaN values <- mean 4.727939586324915
# 0 NaN values <- mean 4.551860715355985
# Output :
#
#        left  right
# 0  5.030000  4.690
# 1  5.025000  4.690
# 2  5.023333  4.690
# 3  5.022500  4.690
# 4  5.020000  4.688
#
#   - - - End interpCsv() - - -
#  >> Already Exist : 視線データ/1214_2_1/nw/補間済
# > Writing 視線データ/1214_2_1/nw/補間済/nw1_pd.csv ...
#
#
# ------------------------------------------
#
#
# > Reading 視線データ/1214_2_1/nw/nw2.csv ...
#
#   - - - Start interpCsv() - - -
#    left  right  leftValid  rightValid
# 0  4.45   4.38          0           0
# 1  4.43   4.38          0           0
# 2  4.45   4.37          0           0
# 3  4.44   4.30          0           0
# 4  4.20   3.95          0           0
# NAの行数:
# left          112
# right          89
# leftValid       0
# rightValid      0
# dtype: int64
# 0 NaN values <- mean 4.700497458073893
# 0 NaN values <- mean 4.498702415127066
# Output :
#
#        left     right
# 0  4.450000  4.380000
# 1  4.440000  4.380000
# 2  4.443333  4.376667
# 3  4.442500  4.357500
# 4  4.394000  4.276000
#
#   - - - End interpCsv() - - -
#  >> Already Exist : 視線データ/1214_2_1/nw/補間済
# > Writing 視線データ/1214_2_1/nw/補間済/nw2_pd.csv ...
#
#
# ------------------------------------------
#
#
# > Reading 視線データ/1214_2_1/nw/nw3.csv ...
#
#   - - - Start interpCsv() - - -
#    left  right  leftValid  rightValid
# 0  4.83   4.55          0           0
# 1  4.84   4.56          0           0
# 2  4.85   4.59          0           0
# 3  4.85   4.59          0           0
# 4  4.86   4.61          0           0
# NAの行数:
# left          481
# right         443
# leftValid       0
# rightValid      0
# dtype: int64
# 0 NaN values <- mean 4.635055289886869
# 0 NaN values <- mean 4.3922687551922595
# Output :
#
#      left     right
# 0  4.8300  4.550000
# 1  4.8350  4.555000
# 2  4.8400  4.566667
# 3  4.8425  4.572500
# 4  4.8460  4.580000
#
#   - - - End interpCsv() - - -
#  >> Already Exist : 視線データ/1214_2_1/nw/補間済
# > Writing 視線データ/1214_2_1/nw/補間済/nw3_pd.csv ...
#
#
# ------------------------------------------
#
#
# > Reading 視線データ/1218_2_2/nw/nw6.csv ...
#
#   - - - Start interpCsv() - - -
#    left  right  leftValid  rightValid
# 0  2.96   3.04          0           0
# 1  2.98   3.06          0           0
# 2  2.97   3.06          0           0
# 3  2.97   3.06          0           0
# 4  2.98   3.05          0           0
# NAの行数:
# left          1439
# right         1445
# leftValid        0
# rightValid       0
# dtype: int64
# 0 NaN values <- mean 3.023482496086873
# 0 NaN values <- mean 3.1303937382383586
# Output :
#
#     left     right
# 0  2.960  3.040000
# 1  2.970  3.050000
# 2  2.970  3.053333
# 3  2.970  3.055000
# 4  2.972  3.054000
#
#   - - - End interpCsv() - - -
#  >> Already Exist : 視線データ/1218_2_2/nw/補間済
# > Writing 視線データ/1218_2_2/nw/補間済/nw6_pd.csv ...
#
#
# ------------------------------------------
#
#
# > Reading 視線データ/1218_2_2/nw/nw4.csv ...
#
#   - - - Start interpCsv() - - -
#    left  right  leftValid  rightValid
# 0   NaN    NaN          4           4
# 1   NaN    NaN          4           4
# 2   NaN    NaN          4           4
# 3   NaN    NaN          4           4
# 4   NaN    NaN          4           4
# NAの行数:
# left          3386
# right         4423
# leftValid        0
# rightValid       0
# dtype: int64
# 48 NaN values <- mean 2.6608210087873685
# 49 NaN values <- mean 2.7424476852280857
# Output :
#
#        left     right
# 0  2.660821  2.742448
# 1  2.660821  2.742448
# 2  2.660821  2.742448
# 3  2.660821  2.742448
# 4  2.660821  2.742448
#
#   - - - End interpCsv() - - -
#  >> Already Exist : 視線データ/1218_2_2/nw/補間済
# > Writing 視線データ/1218_2_2/nw/補間済/nw4_pd.csv ...
#
#
# ------------------------------------------
#
#
# > Reading 視線データ/1218_2_2/nw/nw5.csv ...
#
#   - - - Start interpCsv() - - -
#    left  right  leftValid  rightValid
# 0  2.90   2.88          0           0
# 1  2.89   2.92          0           0
# 2  2.93   2.95          0           0
# 3  2.92   2.97          0           0
# 4  2.93   2.96          0           0
# NAの行数:
# left          823
# right         848
# leftValid       0
# rightValid      0
# dtype: int64
# 0 NaN values <- mean 3.0244412671502263
# 0 NaN values <- mean 3.0316683057378633
# Output :
#
#        left     right
# 0  2.900000  2.880000
# 1  2.895000  2.900000
# 2  2.906667  2.916667
# 3  2.910000  2.930000
# 4  2.914000  2.936000
#
#   - - - End interpCsv() - - -
#  >> Already Exist : 視線データ/1218_2_2/nw/補間済
# > Writing 視線データ/1218_2_2/nw/補間済/nw5_pd.csv ...
#
#
# ------------------------------------------
#
#
# > Reading 視線データ/1218_2_2/nw/nw1.csv ...
#
#   - - - Start interpCsv() - - -
#    left  right  leftValid  rightValid
# 0   NaN    NaN          4           4
# 1   NaN    NaN          4           4
# 2   NaN    NaN          4           4
# 3   NaN    NaN          4           4
# 4   NaN    NaN          4           4
# NAの行数:
# left          1661
# right         1655
# leftValid        0
# rightValid       0
# dtype: int64
# 78 NaN values <- mean 3.0751626260956355
# 36 NaN values <- mean 3.131287905768335
# Output :
#
#        left     right
# 0  3.075163  3.131288
# 1  3.075163  3.131288
# 2  3.075163  3.131288
# 3  3.075163  3.131288
# 4  3.075163  3.131288
#
#   - - - End interpCsv() - - -
#  >> Already Exist : 視線データ/1218_2_2/nw/補間済
# > Writing 視線データ/1218_2_2/nw/補間済/nw1_pd.csv ...
#
#
# ------------------------------------------
#
#
# > Reading 視線データ/1218_2_2/nw/nw2.csv ...
#
#   - - - Start interpCsv() - - -
#    left  right  leftValid  rightValid
# 0   NaN    NaN          4           4
# 1   NaN    NaN          4           4
# 2   NaN    NaN          4           4
# 3   NaN    NaN          4           4
# 4   NaN    NaN          4           4
# NAの行数:
# left          1155
# right         1319
# leftValid        0
# rightValid       0
# dtype: int64
# 34 NaN values <- mean 2.980937648748308
# 106 NaN values <- mean 2.95088017881474
# Output :
#
#        left    right
# 0  2.980938  2.95088
# 1  2.980938  2.95088
# 2  2.980938  2.95088
# 3  2.980938  2.95088
# 4  2.980938  2.95088
#
#   - - - End interpCsv() - - -
#  >> Already Exist : 視線データ/1218_2_2/nw/補間済
# > Writing 視線データ/1218_2_2/nw/補間済/nw2_pd.csv ...
#
#
# ------------------------------------------
#
#
# > Reading 視線データ/1218_2_2/nw/nw3.csv ...
#
#   - - - Start interpCsv() - - -
#    left  right  leftValid  rightValid
# 0  2.74    NaN          0           4
# 1  2.72    NaN          0           4
# 2  2.70    NaN          0           4
# 3  2.68    NaN          0           4
# 4  2.65    NaN          0           4
# NAの行数:
# left          2345
# right         2439
# leftValid        0
# rightValid       0
# dtype: int64
# 0 NaN values <- mean 2.946897755090487
# 39 NaN values <- mean 3.0675929583773214
# Output :
#
#     left     right
# 0  2.740  3.067593
# 1  2.730  3.067593
# 2  2.720  3.067593
# 3  2.710  3.067593
# 4  2.698  3.067593
#
#   - - - End interpCsv() - - -
#  >> Already Exist : 視線データ/1218_2_2/nw/補間済
# > Writing 視線データ/1218_2_2/nw/補間済/nw3_pd.csv ...
#
#
# ------------------------------------------
#
#
# > Reading 視線データ/1211_1_1/bd/bd1.csv ...
#
#   - - - Start interpCsv() - - -
#    left  right  leftValid  rightValid
# 0   NaN   1.66          4           0
# 1   NaN    NaN          4           4
# 2   NaN   1.62          4           0
# 3   NaN   1.83          4           0
# 4   NaN    NaN          4           4
# NAの行数:
# left          2848
# right         2462
# leftValid        0
# rightValid       0
# dtype: int64
# 11 NaN values <- mean 1.9991799507974057
# 0 NaN values <- mean 2.1015613630951853
# Output :
#
#       left   right
# 0  1.99918  1.6600
# 1  1.99918  1.6500
# 2  1.99918  1.6400
# 3  1.99918  1.6875
# 4  1.99918  1.7070
#
#   - - - End interpCsv() - - -
#  >> Already Exist : 視線データ/1211_1_1/bd/補間済
# > Writing 視線データ/1211_1_1/bd/補間済/bd1_pd.csv ...
#
#
# ------------------------------------------
#
#
# > Reading 視線データ/1211_1_1/bd/bd2.csv ...
#
#   - - - Start interpCsv() - - -
#    left  right  leftValid  rightValid
# 0  1.68   2.92          0           0
# 1   NaN   2.33          4           0
# 2   NaN   2.25          4           0
# 3  2.67    NaN          0           4
# 4   NaN   2.71          4           0
# NAの行数:
# left          6054
# right         5229
# leftValid        0
# rightValid       0
# dtype: int64
# 0 NaN values <- mean 1.9403897424755363
# 0 NaN values <- mean 2.275548296724219
# Output :
#
#      left  right
# 0  1.6800  2.920
# 1  1.8450  2.625
# 2  2.0100  2.500
# 3  2.1750  2.495
# 4  2.2356  2.538
#
#   - - - End interpCsv() - - -
#  >> Already Exist : 視線データ/1211_1_1/bd/補間済
# > Writing 視線データ/1211_1_1/bd/補間済/bd2_pd.csv ...
#
#
# ------------------------------------------
#
#
# > Reading 視線データ/1211_1_1/bd/bd3.csv ...
#
#   - - - Start interpCsv() - - -
#    left  right  leftValid  rightValid
# 0   NaN   3.05          4           0
# 1   NaN   3.26          4           0
# 2   NaN   2.47          4           0
# 3   NaN   2.88          4           0
# 4   NaN   2.79          4           0
# NAの行数:
# left          2578
# right         1974
# leftValid        0
# rightValid       0
# dtype: int64
# 5 NaN values <- mean 1.990495919474804
# 0 NaN values <- mean 2.169725228870124
# Output :
#
#        left     right
# 0  1.990496  3.050000
# 1  1.990496  3.155000
# 2  1.990496  2.926667
# 3  1.990496  2.915000
# 4  1.990496  2.890000
#
#   - - - End interpCsv() - - -
#  >> Already Exist : 視線データ/1211_1_1/bd/補間済
# > Writing 視線データ/1211_1_1/bd/補間済/bd3_pd.csv ...
#
#
# ------------------------------------------
#
#
# > Reading 視線データ/1211_1_1/bd/bd6.csv ...
#
#   - - - Start interpCsv() - - -
#    left  right  leftValid  rightValid
# 0   NaN    NaN          4           4
# 1   NaN    NaN          4           4
# 2   NaN    NaN          4           4
# 3   NaN    NaN          4           4
# 4   NaN    NaN          4           4
# NAの行数:
# left          5090
# right         4592
# leftValid        0
# rightValid       0
# dtype: int64
# 76 NaN values <- mean 1.9623402268093784
# 12 NaN values <- mean 2.3050550646189976
# Output :
#
#       left     right
# 0  1.96234  2.305055
# 1  1.96234  2.305055
# 2  1.96234  2.305055
# 3  1.96234  2.305055
# 4  1.96234  2.305055
#
#   - - - End interpCsv() - - -
#  >> Already Exist : 視線データ/1211_1_1/bd/補間済
# > Writing 視線データ/1211_1_1/bd/補間済/bd6_pd.csv ...
#
#
# ------------------------------------------
#
#
# > Reading 視線データ/1211_1_1/bd/bd4.csv ...
#
#   - - - Start interpCsv() - - -
#    left  right  leftValid  rightValid
# 0   NaN   2.04          4           0
# 1   NaN   1.93          4           0
# 2   NaN   1.92          4           0
# 3   NaN   2.50          4           0
# 4   NaN   2.13          4           0
# NAの行数:
# left          6820
# right         5822
# leftValid        0
# rightValid       0
# dtype: int64
# 26 NaN values <- mean 1.9755891509710657
# 0 NaN values <- mean 2.082493310298597
# Output :
#
#        left     right
# 0  1.975589  2.040000
# 1  1.975589  1.985000
# 2  1.975589  1.963333
# 3  1.975589  2.097500
# 4  1.975589  2.104000
#
#   - - - End interpCsv() - - -
#  >> Already Exist : 視線データ/1211_1_1/bd/補間済
# > Writing 視線データ/1211_1_1/bd/補間済/bd4_pd.csv ...
#
#
# ------------------------------------------
#
#
# > Reading 視線データ/1211_1_1/bd/bd5.csv ...
#
#   - - - Start interpCsv() - - -
#    left  right  leftValid  rightValid
# 0    sy    NaN          4           4
# 1  2.79    NaN          0           4
# 2  2.68    NaN          0           4
# 3  3.18    NaN          0           4
# 4   NaN    NaN          4           4
# NAの行数:
# left          4789
# right         4297
# leftValid        0
# rightValid       0
# dtype: int64
# 1784 NaN values <- mean 2.062645104041996
# 7 NaN values <- mean 1.9685579367292758
# Output :
#
#        left     right
# 0  2.062645  1.968558
# 1  2.790000  1.968558
# 2  2.735000  1.968558
# 3  2.883333  1.968558
# 4  2.883333  1.968558
#
#   - - - End interpCsv() - - -
#  >> Already Exist : 視線データ/1211_1_1/bd/補間済
# > Writing 視線データ/1211_1_1/bd/補間済/bd5_pd.csv ...
#
#
# ------------------------------------------
#
#
# > Reading 視線データ/1211_1_1/nw/nw6.csv ...
#
#   - - - Start interpCsv() - - -
#    left  right  leftValid  rightValid
# 0   NaN    NaN        4.0         4.0
# 1  1.95   2.16        0.0         0.0
# 2   NaN    NaN        4.0         4.0
# 3   NaN    NaN        4.0         4.0
# 4   NaN   1.94        4.0         0.0
# NAの行数:
# left          3352
# right         2770
# leftValid        2
# rightValid       2
# dtype: int64
# 1 NaN values <- mean 2.019022375466355
# 1 NaN values <- mean 2.1907136633227213
# Output :
#
#        left     right
# 0  2.019022  2.190714
# 1  1.950000  2.160000
# 2  1.948030  2.123333
# 3  1.946061  2.086667
# 4  1.944091  2.050000
#
#   - - - End interpCsv() - - -
#  >> Already Exist : 視線データ/1211_1_1/nw/補間済
# > Writing 視線データ/1211_1_1/nw/補間済/nw6_pd.csv ...
#
#
# ------------------------------------------
#
#
# > Reading 視線データ/1211_1_1/nw/nw4.csv ...
#
#   - - - Start interpCsv() - - -
#    left  right  leftValid  rightValid
# 0   NaN    NaN          4           4
# 1   NaN    NaN          4           4
# 2   NaN    NaN          4           4
# 3   NaN    NaN          4           4
# 4   NaN   1.65          4           0
# NAの行数:
# left          4844
# right         3837
# leftValid        0
# rightValid       0
# dtype: int64
# 39 NaN values <- mean 2.0651244561171143
# 4 NaN values <- mean 2.2364362159105076
# Output :
#
#        left     right
# 0  2.065124  2.236436
# 1  2.065124  2.236436
# 2  2.065124  2.236436
# 3  2.065124  2.236436
# 4  2.065124  1.650000
#
#   - - - End interpCsv() - - -
#  >> Already Exist : 視線データ/1211_1_1/nw/補間済
# > Writing 視線データ/1211_1_1/nw/補間済/nw4_pd.csv ...
#
#
# ------------------------------------------
#
#
# > Reading 視線データ/1211_1_1/nw/nw5.csv ...
#
#   - - - Start interpCsv() - - -
#    left  right  leftValid  rightValid
# 0   NaN    NaN          4           4
# 1   NaN    NaN          4           4
# 2  1.75    NaN          0           4
# 3  1.70    NaN          0           4
# 4   NaN    NaN          4           4
# NAの行数:
# left          1740
# right         1471
# leftValid        0
# rightValid       0
# dtype: int64
# 2 NaN values <- mean 2.033711899222274
# 10 NaN values <- mean 2.2197652954757907
# Output :
#
#        left     right
# 0  2.033712  2.219765
# 1  2.033712  2.219765
# 2  1.750000  2.219765
# 3  1.725000  2.219765
# 4  1.722381  2.219765
#
#   - - - End interpCsv() - - -
#  >> Already Exist : 視線データ/1211_1_1/nw/補間済
# > Writing 視線データ/1211_1_1/nw/補間済/nw5_pd.csv ...
#
#
# ------------------------------------------
#
#
# > Reading 視線データ/1211_1_1/nw/nw1.csv ...
#
#   - - - Start interpCsv() - - -
#    left  right  leftValid  rightValid
# 0  3.47   3.25          0           0
# 1  3.45   3.36          0           0
# 2  3.47   3.31          0           0
# 3  3.44   3.11          0           0
# 4  3.36   3.19          0           0
# NAの行数:
# left          2745
# right         2640
# leftValid        0
# rightValid       0
# dtype: int64
# 0 NaN values <- mean 2.509233525455066
# 0 NaN values <- mean 2.558376131677548
# Output :
#
#        left     right
# 0  3.470000  3.250000
# 1  3.460000  3.305000
# 2  3.463333  3.306667
# 3  3.457500  3.257500
# 4  3.438000  3.244000
#
#   - - - End interpCsv() - - -
#  >> Already Exist : 視線データ/1211_1_1/nw/補間済
# > Writing 視線データ/1211_1_1/nw/補間済/nw1_pd.csv ...
#
#
# ------------------------------------------
#
#
# > Reading 視線データ/1211_1_1/nw/nw2.csv ...
#
#   - - - Start interpCsv() - - -
#    left  right  leftValid  rightValid
# 0   NaN    NaN          4           4
# 1  4.05    NaN          0           4
# 2  3.10    NaN          0           4
# 3  3.28   2.45          0           0
# 4  3.44   2.55          0           0
# NAの行数:
# left          1741
# right         1249
# leftValid        0
# rightValid       0
# dtype: int64
# 1 NaN values <- mean 2.495466407502562
# 3 NaN values <- mean 2.7205775926769844
# Output :
#
#        left     right
# 0  2.495466  2.720578
# 1  4.050000  2.720578
# 2  3.575000  2.720578
# 3  3.476667  2.450000
# 4  3.467500  2.500000
#
#   - - - End interpCsv() - - -
#  >> Already Exist : 視線データ/1211_1_1/nw/補間済
# > Writing 視線データ/1211_1_1/nw/補間済/nw2_pd.csv ...
#
#
# ------------------------------------------
#
#
# > Reading 視線データ/1211_1_1/nw/nw3.csv ...
#
#   - - - Start interpCsv() - - -
#    left  right  leftValid  rightValid
# 0   NaN    NaN          4           4
# 1   NaN    NaN          4           4
# 2   NaN    NaN          4           4
# 3   NaN    NaN          4           4
# 4   NaN    NaN          4           4
# NAの行数:
# left          5957
# right         4191
# leftValid        0
# rightValid       0
# dtype: int64
# 8 NaN values <- mean 2.299650115315373
# 7 NaN values <- mean 2.406092974807082
# Output :
#
#       left     right
# 0  2.29965  2.406093
# 1  2.29965  2.406093
# 2  2.29965  2.406093
# 3  2.29965  2.406093
# 4  2.29965  2.406093
#
#   - - - End interpCsv() - - -
#  >> Already Exist : 視線データ/1211_1_1/nw/補間済
# > Writing 視線データ/1211_1_1/nw/補間済/nw3_pd.csv ...
#
#
# ------------------------------------------
#
#
# > Reading 視線データ/1207_1_1/bd/bd1.csv ...
#
#   - - - Start interpCsv() - - -
#    left  right  leftValid  rightValid
# 0  3.09   3.02          0           0
# 1  3.09   3.01          0           0
# 2  3.09   3.02          0           0
# 3  3.09   3.02          0           0
# 4  3.11   3.02          0           0
# NAの行数:
# left          226
# right         234
# leftValid       0
# rightValid      0
# dtype: int64
# 0 NaN values <- mean 3.143757220511811
# 0 NaN values <- mean 2.9709572440724243
# Output :
#
#     left     right
# 0  3.090  3.020000
# 1  3.090  3.015000
# 2  3.090  3.016667
# 3  3.090  3.017500
# 4  3.094  3.018000
#
#   - - - End interpCsv() - - -
#  >> Already Exist : 視線データ/1207_1_1/bd/補間済
# > Writing 視線データ/1207_1_1/bd/補間済/bd1_pd.csv ...
#
#
# ------------------------------------------
#
#
# > Reading 視線データ/1207_1_1/bd/bd2.csv ...
#
#   - - - Start interpCsv() - - -
#    left  right  leftValid  rightValid
# 0  3.28   3.01          0           0
# 1  3.28   3.01          0           0
# 2  3.27   3.00          0           0
# 3  3.27   3.00          0           0
# 4  3.26   2.99          0           0
# NAの行数:
# left          586
# right         598
# leftValid       0
# rightValid      0
# dtype: int64
# 0 NaN values <- mean 3.0865831569442013
# 0 NaN values <- mean 2.955634229634008
# Output :
#
#        left     right
# 0  3.280000  3.010000
# 1  3.280000  3.010000
# 2  3.276667  3.006667
# 3  3.275000  3.005000
# 4  3.272000  3.002000
#
#   - - - End interpCsv() - - -
#  >> Already Exist : 視線データ/1207_1_1/bd/補間済
# > Writing 視線データ/1207_1_1/bd/補間済/bd2_pd.csv ...
#
#
# ------------------------------------------
#
#
# > Reading 視線データ/1207_1_1/bd/bd3.csv ...
#
#   - - - Start interpCsv() - - -
#    left  right  leftValid  rightValid
# 0     s   2.98          0           0
# 1  3.07   2.97          0           0
# 2  3.07   2.97          0           0
# 3  3.06   2.97          0           0
# 4  3.06   2.96          0           0
# NAの行数:
# left          190
# right         211
# leftValid       0
# rightValid      0
# dtype: int64
